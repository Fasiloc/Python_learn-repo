# %% [markdown]
# <a href="https://colab.research.google.com/github/Fasiloc/Python_learn-repo/blob/main/Mini%20Project/Assessment_Project_Fasil_oc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Analysis 1 - Banking sector - Axis bank hdfc bank

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
data1=pd.read_csv('/content/AXISBANK.csv')
data1['Date']=data1['Date'].astype('datetime64[ns]')
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1291 entries, 0 to 1290
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1291 non-null   datetime64[ns]
#  1   High       1291 non-null   float64
#  2   Low        1291 non-null   float64
#  3   Open       1291 non-null   float64
#  4   Close      1291 non-null   float64
#  5   Volume     1291 non-null   float64
#  6   Adj Close  1291 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 70.7 KB

# %%
data1[1020:1200]
# Out:
#            Date        High         Low  ...       Close      Volume   Adj Close
# 1020 2020-02-25  732.000000  722.049988  ...  728.750000   5419596.0  728.750000
# 1021 2020-02-26  735.750000  722.000000  ...  729.400024   7136975.0  729.400024
# 1022 2020-02-27  739.450012  716.549988  ...  735.849976   8867328.0  735.849976
# 1023 2020-02-28  724.700012  691.000000  ...  697.299988  16428944.0  697.299988
# 1024 2020-03-02  713.250000  675.299988  ...  684.200012  13854352.0  684.200012
# ...         ...         ...         ...  ...         ...         ...         ...
# 1195 2020-11-06  546.000000  531.200012  ...  541.750000  22256961.0  541.750000
# 1196 2020-11-09  568.000000  548.250000  ...  565.049988  26041462.0  565.049988
# 1197 2020-11-10  588.000000  568.250000  ...  583.599976  34935409.0  583.599976
# 1198 2020-11-11  611.150024  576.400024  ...  608.650024  50289937.0  608.650024
# 1199 2020-11-12  610.450012  588.799988  ...  599.700012  34244439.0  599.700012
#
# ...

# %%
data2=pd.read_csv('/content/HDFCBANK.csv')
data2['Date']=data1['Date'].astype('datetime64[ns]')
data2[1020:1200]
# Out:
#            Date         High          Low  ...        Close      Volume    Adj Close
# 1020 2020-02-25  1209.000000  1198.000000  ...  1200.300049   6943340.0  1200.300049
# 1021 2020-02-26  1204.699951  1185.650024  ...  1199.250000   6907393.0  1199.250000
# 1022 2020-02-27  1202.500000  1181.000000  ...  1199.449951  10327549.0  1199.449951
# 1023 2020-02-28  1185.000000  1170.099976  ...  1177.650024  12156528.0  1177.650024
# 1024 2020-03-02  1201.150024  1166.150024  ...  1179.599976   7332449.0  1179.599976
# ...         ...          ...          ...  ...          ...         ...          ...
# 1195 2020-11-06  1310.000000  1265.500000  ...  1307.650024  17852862.0  1307.650024
# 1196 2020-11-09  1345.949951  1315.199951  ...  1340.550049  13144220.0  1340.550049
# 1197 2020-11-10  1395.000000  1351.550049  ...  1393.650024  20758678.0  1393.650024
# 1198 2020-11-11  1414.800049  1370.500000  ...  1389.949951  18058097.0  1389.949951
# ...

# %%
data3=pd.read_csv('/content/TCS.csv')
data3['Date']=data1['Date'].astype('datetime64[ns]')
data3[1020:1200]
# Out:
#            Date         High          Low  ...        Close     Volume    Adj Close
# 1197 2020-11-10  3572.000000  3445.850098  ...  3508.350098   976298.0  3508.350098
# 1198 2020-11-11  3541.600098  3453.050049  ...  3492.750000  1141508.0  3492.750000
# ...

# %%
data6=pd.read_csv('/content/ITC.csv')
data6['Date']=data1['Date'].astype('datetime64[ns]')

# %%
data7=pd.read_csv('/content/POWERGRID.csv')
data7['Date']=data1['Date'].astype('datetime64[ns]')

# %%
data8=pd.read_csv('/content/ONGC.csv')
data8['Date']=data1['Date'].astype('datetime64[ns]')

# %%
data9=pd.read_csv('/content/MARUTI.csv')
data9['Date']=data1['Date'].astype('datetime64[ns]')

# %%
data10=pd.read_csv('/content/TATAMOTORS.csv')
data10['Date']=data1['Date'].astype('datetime64[ns]')

# %%
data11=pd.read_csv('/content/SUNPHARMA.csv')
data11['Date']=data1['Date'].astype('datetime64[ns]')

# %%
data12=pd.read_csv('/content/CIPLA.csv')
data12['Date']=data1['Date'].astype('datetime64[ns]')

# %%
figure(figsize=(8, 6), dpi=120)
plt.subplots_adjust( wspace=0.5, 
                    hspace=1)
plt.subplot(3,2,1)
plt.plot(data1.loc[1000:,["Date"]],data1.loc[1000:,["Close"]],label='Axis Bank')
plt.plot(data2.loc[1000:,["Date"]],data2.loc[1000:,["Close"]],label='HDFC Bank')
plt.title('Bank Sector')
plt.xlabel("Date")
plt.ylabel("Clossing Value")
plt.legend()
plt.grid()
plt.show

plt.subplot(3,2,2)
plt.plot(data3.loc[1000:,["Date"]],data3.loc[1000:,["Close"]],label='TCS')
plt.plot(data4.loc[1000:,["Date"]],data4.loc[1000:,["Close"]],label='WIPRO')
plt.title('IT Sector')
plt.xlabel("Date")
plt.ylabel("Clossing Value")
plt.legend()
plt.grid()
plt.show

plt.subplot(3,2,3)
plt.plot(data5.loc[1000:,["Date"]],data5.loc[1000:,["Close"]],label='Britania')
plt.plot(data6.loc[1000:,["Date"]],data6.loc[1000:,["Close"]],label='ITC')
plt.title('FMCG Sector')
plt.xlabel("Date")
plt.ylabel("Clossing Value")
plt.legend()
plt.grid()
plt.show


plt.subplot(3,2,4)
plt.plot(data7.loc[1000:,["Date"]],data7.loc[1000:,["Close"]],label='Power Grid')
plt.plot(data8.loc[1000:,["Date"]],data8.loc[1000:,["Close"]],label='ONGC')
plt.title('Public Sector')
plt.xlabel("Date")
plt.ylabel("Clossing Value")
plt.legend()
plt.grid()
plt.show


plt.subplot(3,2,5)
plt.plot(data9.loc[1000:,["Date"]],data9.loc[1000:,["Close"]],label='Maruti')
plt.plot(data10.loc[1000:,["Date"]],data10.loc[1000:,["Close"]],label='TATA Motors')
plt.title('Automobile Sector')
plt.xlabel("Date")
plt.ylabel("Clossing Value")
plt.legend()
plt.grid()
plt.show


plt.subplot(3,2,6)
plt.plot(data11.loc[1000:,["Date"]],data11.loc[1000:,["Close"]],label='Sun Pharma')
plt.plot(data12.loc[1000:,["Date"]],data12.loc[1000:,["Close"]],label='Cipla')
plt.title('Pharmaceutical Sector')
plt.xlabel("Date")
plt.ylabel("Clossing Value")
plt.legend()
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show>
