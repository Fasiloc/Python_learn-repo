# %% [markdown]
# <a href="https://colab.research.google.com/github/Fasiloc/Python_learn-repo/blob/main/Classes/Day_14_Drop_fill_replace_and_interpolate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing pandas package
import pandas as pd
import numpy as np

# %%
# reading data from csv file
data = pd.read_csv("/content/employees.csv")

# %%
data.head(10)
# Out:
#   FirstName  Gender  ... Senior Management                  Team
# 0   Douglas    Male  ...              True             Marketing
# 1    Thomas    Male  ...              True                   NaN
# 2     Maria  Female  ...             False               Finance
# 3     Jerry    Male  ...              True               Finance
# 4     Larry    Male  ...              True       Client Services
# 5    Dennis    Male  ...             False                 Legal
# 6      Ruby  Female  ...              True               Product
# 7       NaN  Female  ...               NaN               Finance
# 8    Angela  Female  ...              True           Engineering
# 9   Frances  Female  ...              True  Business Development
#
# [10 rows x 8 columns]

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.head(20)
# Out:
#    FirstName  Gender  ... Senior Management                  Team
# 0    Douglas    Male  ...              True             Marketing
# 1     Thomas    Male  ...              True                   NaN
# 2      Maria  Female  ...             False               Finance
# 3      Jerry    Male  ...              True               Finance
# 4      Larry    Male  ...              True       Client Services
# 5     Dennis    Male  ...             False                 Legal
# 6       Ruby  Female  ...              True               Product
# 7        NaN  Female  ...               NaN               Finance
# 8     Angela  Female  ...              True           Engineering
# 9    Frances  Female  ...              True  Business Development
# 10    Louise  Female  ...              True                   NaN
# 11     Julie  Female  ...              True                 Legal
# 12   Brandon    Male  ...              True       Human Resources
# ...

# %%
bool_series = pd.isnull(data["Team"])

# %%
bool_series
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Team, Length: 1000, dtype: bool

# %%
data[bool_series]
# Out:
#        FirstName  Gender  Start Date  ... Bonus %  Senior Management  Team
# 1         Thomas    Male   3/31/1996  ...   4.170               True   NaN
# 10        Louise  Female  08-12-1980  ...  15.132               True   NaN
# 23           NaN    Male   6/14/2012  ...   5.042                NaN   NaN
# 32           NaN    Male   8/21/1998  ...   6.417                NaN   NaN
# 91         James     NaN   1/26/2005  ...   8.309              False   NaN
# 109  Christopher    Male   4/22/2000  ...  11.449              False   NaN
# 139          NaN  Female  10-03-1990  ...  10.527                NaN   NaN
# 199     Jonathan    Male   7/17/2009  ...  16.736               True   NaN
# 258      Michael    Male   1/24/2002  ...  12.659              False   NaN
# 290       Jeremy    Male   6/14/1988  ...  13.657               True   NaN
# 314        Bobby    Male   3/31/1996  ...   6.338              False   NaN
# ...

# %%
bool_series = pd.notnull(data["Gender"])

# %%
data[bool_series]
# Out:
#     FirstName  Gender  ... Senior Management                  Team
# 0     Douglas    Male  ...              True             Marketing
# 1      Thomas    Male  ...              True                   NaN
# 2       Maria  Female  ...             False               Finance
# 3       Jerry    Male  ...              True               Finance
# 4       Larry    Male  ...              True       Client Services
# ..        ...     ...  ...               ...                   ...
# 994    George    Male  ...              True             Marketing
# 996   Phillip    Male  ...             False               Finance
# 997   Russell    Male  ...             False               Product
# 998     Larry    Male  ...             False  Business Development
# 999    Albert    Male  ...              True                 Sales
#
# [855 rows x 8 columns]

# %%
# drops all the null 
df=data.dropna()
print(df)
# Out:
#     FirstName  Gender  ... Senior Management                  Team
# 0     Douglas    Male  ...              True             Marketing
# 2       Maria  Female  ...             False               Finance
# 3       Jerry    Male  ...              True               Finance
# 4       Larry    Male  ...              True       Client Services
# 5      Dennis    Male  ...             False                 Legal
# ..        ...     ...  ...               ...                   ...
# 994    George    Male  ...              True             Marketing
# 996   Phillip    Male  ...             False               Finance
# 997   Russell    Male  ...             False               Product
# 998     Larry    Male  ...             False  Business Development
# 999    Albert    Male  ...              True                 Sales
#
# [764 rows x 8 columns]

# %%
df.shape
# Out:
# (764, 8)

# %%
data=pd.read_csv('/content/Toyota.csv')
data.head
# Out:
# <bound method NDFrame.head of       Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0              0  13500  23.0  46986  ...         0  2000  three    1165
# 1              1  13750  23.0  72937  ...         0  2000      3    1165
# 2              2  13950  24.0  41711  ...         0  2000      3    1165
# 3              3  14950  26.0  48000  ...         0  2000      3    1165
# 4              4  13750  30.0  38500  ...         0  2000      3    1170
# ...          ...    ...   ...    ...  ...       ...   ...    ...     ...
# 1431        1431   7500   NaN  20544  ...         0  1300      3    1025
# 1432        1432  10845  72.0     ??  ...         0  1300      3    1015
# 1433        1433   8500   NaN  17016  ...         0  1300      3    1015
# 1434        1434   7250  70.0     ??  ...         0  1300      3    1015
# 1435        1435   6950  76.0      1  ...         0  1600      5    1114
#
# [1436 rows x 11 columns]>

# %%
nu=pd.isnull(data['Age'])
nu
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1431     True
# 1432    False
# 1433     True
# 1434    False
# 1435    False
# Name: Age, Length: 1436, dtype: bool

# %%
data[nu]
# Out:
#       Unnamed: 0  Price  Age     KM  ... Automatic    CC  Doors  Weight
# 33            33  14950  NaN  32692  ...         0  1400      3    1100
# 55            55  13250  NaN  45725  ...         0  1600      5    1075
# 83            83  17950  NaN  16238  ...         1  1600      5    1180
# 92            92  19950  NaN  34472  ...         0  1995      3    1260
# 105          105  16950  NaN  13748  ...         0  1400      3    1100
# ...          ...    ...  ...    ...  ...       ...   ...    ...     ...
# 1416        1416   8950  NaN  40093  ...         0  1600      5    1114
# 1422        1422   7600  NaN  36000  ...         0  1600      3    1050
# 1427        1427   8950  NaN  29000  ...         1  1300      3    1045
# 1431        1431   7500  NaN  20544  ...         0  1300      3    1025
# 1433        1433   8500  NaN  17016  ...         0  1300      3    1015
#
# [100 rows x 11 columns]

# %%
nnu=pd.notnull(data['Price'])
nnu
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1431    True
# 1432    True
# 1433    True
# 1434    True
# 1435    True
# Name: Price, Length: 1436, dtype: bool

# %%
newdata[nnu]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-d6b3fc67b178> in <module>()
# ----> 1 newdata[nnu]
#
# NameError: name 'newdata' is not defined

# %%
df.loc[]
